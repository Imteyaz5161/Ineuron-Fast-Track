# %%
import pandas as pd

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df1.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age' , 'GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1.to_csv('NBA.csv',index=False)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9CD5-FCE1
#
#  Directory of C:\Users\mdimt
#
# 14-11-2022  15:31            36,257  12th Nov Live Class Functions revision.ipynb
# 07-12-2022  00:06           501,204  Working with Pandas day2 revision.ipynb
# 07-12-2022  00:06    <DIR>          .
# 07-12-2022  00:06    <DIR>          ..
# 06-11-2022  21:59    <DIR>          .anaconda
# 06-11-2022  23:06    <DIR>          .conda
# 22-05-2021  01:35                25 .condarc
# 22-05-2021  01:35    <DIR>          .continuum
# 19-10-2022  20:09                53 .git-for-windows-updater
# 01-07-2021  23:01    <DIR>          .idlerc
# 06-12-2022  22:17    <DIR>          .ipynb_checkpoints
# 22-05-2021  01:39    <DIR>          .ipython
# 29-10-2022  16:59    <DIR>          .jupyter
# 06-06-2021  02:13    <DIR>          .matplotlib
# 26-10-2022  17:39    <DIR>          .spyder-py3
# 07-10-2022  21:43    <DIR>          .vscode
# 15-11-2022  22:42    <DIR>          __pycache__
# 28-10-2022  22:49        23,553,184 1.Python Fundamentals and Advanced Python.zip
# 14-11-2022  22:32            25,125 13th Nov Live Class Functions 4 revision.ipynb
# 25-11-2022  22:47    <DIR>          19.3 MongoDB
# 23-11-2022  20:02         4,407,102 19.3 MongoDB.7z
# 31-10-2022  17:35            21,059 29th Oct Live Class Function Basic Revision.ipynb
# 21-05-2021  04:09    <DIR>          3D Objects
# 26-11-2022  16:13            27,352 6thMarch-20220803T090951Z-001.zip
# 26-11-2022  22:26             1,173 addresses.csv
# 22-05-2021  01:14    <DIR>          anaconda3
# 26-11-2022  21:17         3,381,768 archive.zip
# 21-10-2022  00:42            10,061 Assignment_1.docx
# 26-11-2022  15:50                 0 Bag of Words
# 04-12-2022  21:55           461,474 bank.csv
# 04-12-2022  21:55         4,610,348 bank-full.csv
# 04-12-2022  21:54             3,864 bank-names.txt
# 18-11-2022  17:27            51,867 car.data
# 24-11-2022  16:37           628,633 carbon_nanotubes.csv
# 19-11-2022  23:43            19,879 class assignment oops.ipynb
# 26-11-2022  16:13            79,472 class_task_MongoDB_SQlite.pdf
# 26-11-2022  16:13       120,256,543 classTask_MongoDB_SQLite-20220803T085516Z-001.zip
# 21-05-2021  04:09    <DIR>          Contacts
# 26-11-2022  22:26             1,589 contacts.csv
# 01-07-2021  23:11    <DIR>          Credit Card Risk Assessment
# 28-11-2022  18:49             5,845 cricket.csv
# 20-10-2022  20:18            59,629 demo_002.ipynb
# 26-10-2022  15:57            57,559 demo_003.ipynb
# 20-10-2022  20:20            45,893 demo_2 live_classes_ineuron_revision.ipynb
# 15-11-2022  22:42                 0 dict.log
# 21-05-2021  04:18    <DIR>          Documents
# 26-11-2022  15:46        12,313,965 docword.enron.txt.gz
# 26-11-2022  15:45         1,053,803 docword.kos.txt.gz
# 26-11-2022  15:45         2,288,169 docword.nips.txt.gz
# 26-11-2022  16:09       234,225,967 docword.nytimes.txt.gz
# 06-12-2022  23:46    <DIR>          Downloads
# 16-11-2022  13:52         3,116,878 eda_data.csv
# 19-11-2022  23:45            13,907 Exception Handling Class 2.ipynb
# 08-11-2022  21:26             9,192 Exception Handling Class1 Part1.ipynb
# 21-05-2021  04:09    <DIR>          Favorites
# 03-11-2022  00:26            10,428 For Loop & While Loops Revision.ipynb
# 03-11-2022  15:20            25,890 for loops while loop.ipynb
# 14-10-2022  00:42            10,742 FSDS_bootcamp_assignment_002_Oct_01.ipynb
# 28-10-2022  19:31             5,294 FSDS_bootcamp_assignment_004_Oct_09 (1).ipynb
# 07-11-2022  17:43            31,508 Function and holiday task.ipynb
# 06-11-2022  20:52            60,343 Function continued.ipynb
# 04-11-2022  02:08            18,716 function part1.ipynb
# 06-11-2022  00:28            62,066 function part2.ipynb
# 08-11-2022  14:44             1,763 functions task 20 question.txt
# 16-11-2022  23:44            11,903 glass.data
# 16-11-2022  13:52         3,835,251 glassdoor_jobs.csv
# 09-11-2022  22:09            43,659 holiday 20 assignment.ipynb
# 26-11-2022  22:26               277 holiday_schedules.csv
# 25-11-2022  22:44             8,192 ineuron.db
# 09-11-2022  17:43            23,501 Iterator Generator File System.ipynb
# 08-11-2022  02:20        21,685,761 iterator generator.ipynb
# 01-07-2021  23:12    <DIR>          Jedi
# 25-11-2022  19:04            12,288 jobdb.db
# 28-11-2022  18:49            35,082 json_res.csv
# 30-06-2021  14:39                 0 jupyter
# 12-05-2022  12:24    <DIR>          Links
# 26-10-2022  15:42             9,919 live_3demo_classes_ineuron_revision.ipynb
# 30-10-2022  00:07            16,593 live_classes_revision_29oct.ipynb
# 26-11-2022  22:26            18,015 locations.csv
# 15-11-2022  22:24             5,993 logging (1).ipynb
# 10-11-2022  01:53             6,194 Logging class.ipynb
# 27-11-2022  01:02           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 27-11-2022  01:02           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 27-11-2022  01:02            95,503 LUSID Excel - Manage instruments with economic definitions.xlsx
# 27-11-2022  01:02            84,319 LUSID Excel - Manage Orders.xlsx
# 27-11-2022  01:02           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 27-11-2022  01:02           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 27-11-2022  01:02           136,632 LUSID Excel - Setting up your market data.xlsx
# 26-11-2022  22:26             1,610 mail_addresses.csv
# 23-10-2022  00:20    <DIR>          Microsoft
# 19-11-2022  23:43            10,625 Module_Packages.ipynb
# 24-11-2022  16:59            75,694 mongo db class1 revision.ipynb
# 24-11-2022  20:39            57,341 mongodb class 1.ipynb
# 28-05-2022  11:32    <DIR>          Music
# 15-11-2022  22:55                 0 mydict.py
# 07-12-2022  00:07            78,961 NBA.csv
# 06-11-2022  23:23           163,679 nbextensions.ipynb
# 26-11-2022  16:11            30,814 numpy day 2.ipynb
# 06-12-2022  01:07    <DIR>          OneDrive
# 13-11-2022  22:07            39,946 oops 29th .ipynb
# 15-11-2022  22:28            43,392 oops 30th.ipynb
# 19-11-2022  23:45            41,465 oops class 1.ipynb
# 13-11-2022  19:09            40,284 Oops class part2.ipynb
# 15-11-2022  22:29            44,127 OOPs Concepts Polymorphism revision.ipynb

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')
# Out:
# 19-11-2022  23:45            11,842 Oops part1 revision.ipynb
# 26-11-2022  22:26             2,281 organizations.csv
# 26-11-2022  16:11            74,683 pandas and numpy.ipynb
# 06-12-2022  23:38           130,610 pandas class 3.ipynb
# 06-12-2022  22:17           195,692 Pandas Data Analysis Part 1 class task.ipynb
# 03-12-2022  20:25           131,403 Pandas Data Analysis Part 1 revision.ipynb
# 06-12-2022  23:58           532,860 pandas day 2.ipynb
# 06-12-2022  20:09           167,780 pandas day4 revision.ipynb
# 27-11-2022  01:06           416,711 Pandas revision.ipynb
# 25-11-2022  22:44             8,192 person.db
# 26-11-2022  22:26             2,092 phones.csv
# 23-06-2021  13:35            66,519 Pridiction Using Supervised ML.ipynb
# 24-10-2022  18:23            12,891 Programming_Assingment1.docx
# 26-11-2022  22:26                60 programs.csv
# 11-11-2022  20:19    <DIR>          PycharmProjects
# 05-11-2022  21:58             6,891 Python Basic Assignment 3.ipynb
# 08-11-2022  20:09            12,206 Python Basic Assignment 4.ipynb
# 10-11-2022  21:05             5,807 Python Basic Assignment 5.ipynb
# 15-11-2022  02:10            10,370 Python Basic Assignment 6.ipynb
# 16-11-2022  19:53             5,038 Python Basic Program Assignment 6.ipynb
# 24-11-2022  17:23             5,372 Python Basic Program Assignment 7.ipynb
# 04-12-2022  01:48             7,840 Python Basic Program Assignment 8.ipynb
# 07-11-2022  16:48            11,860 Python Basic Programming Assignment 3.ipynb
# 11-11-2022  20:38             8,306 Python Basic Programming Assignment 4.ipynb
# 14-11-2022  00:30             6,153 Python Basic Programming Assignment 5.ipynb
# 03-11-2022  20:47            14,188 Python Basics Assignment 2.ipynb
# 19-11-2022  01:20            18,535 Python Basics Assignment 7.ipynb
# 24-11-2022  23:59            12,254 Python Basics Assignment 8.ipynb
# 30-10-2022  22:54             8,022 Python Basics Assignment_1.ipynb
# 01-11-2022  15:22             8,022 Python Basics Assignment1.ipynb
# 24-10-2022  19:21             4,080 Python Basics Program Assignment1.ipynb
# 27-10-2022  21:07             4,753 Python Basics Programming_Assignment_2.ipynb
# 26-11-2022  15:45             2,170 readme.txt
# 26-11-2022  22:26               350 regular_schedules.csv
# 16-11-2022  13:52         3,100,978 salary_data_cleaned.csv
# 21-05-2021  04:09    <DIR>          Saved Games
# 04-07-2021  01:33    <DIR>          seaborn-data
# 12-05-2022  12:24    <DIR>          Searches
# 26-11-2022  22:26            19,128 services.csv
# 23-11-2022  22:57                22 Setup.zip
# 18-11-2022  21:00            80,157 SQL basic .ipynb
# 19-11-2022  23:45           358,211 sql day 2 .ipynb
# 05-12-2022  20:26            14,248 SQL lite, map, reduce, filter, zip Assignment.ipynb
# 26-11-2022  15:50            85,137 SQL lite, map, reduce, filter,zip revision.ipynb
# 18-11-2022  19:21           118,377 SQL part 1 revision.ipynb
# 25-11-2022  16:21           315,007 SQL part2 revision.ipynb
# 25-11-2022  22:42            45,270 SQLLITE ,map ,reduce ,filter,zip.ipynb
# 28-07-2021  16:17           341,881 Statistics with data science project.ipynb
# 26-11-2022  20:47             7,786 submission.csv
# 26-11-2022  22:26            14,618 taxonomy.csv
# 10-11-2022  01:52             1,807 test.log
# 03-07-2021  00:56             6,182 Test.png
# 08-11-2022  21:00                20 test.text
# 12-11-2022  15:45                 0 test1.py
# 13-11-2022  16:03                22 test1.txt
# 12-11-2022  20:51                 0 test2.py
# 13-11-2022  21:41                30 test2.tex
# 12-11-2022  15:39                 7 test3.py
# 12-11-2022  16:13                 0 test4.py
# 09-11-2022  20:02                 0 test43
# 24-06-2021  13:43            66,589 TSF GRIP Task 1 Imteyaz.ipynb
# 23-06-2021  14:11            66,518 TSF GRIP Task 1 Imteyaz-Copy1.ipynb
# 09-11-2022  19:26                22 tsst1.txt
# 06-07-2021  01:55             2,219 Tutorial 10- Seaborn- Countplot(), Violinplot(), Boxplot()- Part2.ipynb
# 03-07-2021  16:43           142,418 Tutorial 8- Matplotlib (Simple Visualization Library).ipynb
# 06-07-2021  01:46           355,324 Tutorial 9- Seaborn Tutorial- Distplot, Joinplot, Pairplot Part 1.ipynb
# 26-11-2022  16:30       201,228,288 Unconfirmed 19321.crdownload
# 02-07-2021  19:54             5,906 Untitled.ipynb
# 21-10-2022  00:41                 0 untitled.txt
# 02-07-2021  22:10            14,709 Untitled1.ipynb
# 04-11-2022  18:57            19,366 Untitled10.ipynb
# 14-11-2022  23:35            12,197 Untitled11.ipynb
# 06-11-2022  21:12            11,238 Untitled12.ipynb
# 21-11-2022  01:34             3,746 Untitled13.ipynb
# 22-11-2022  20:43           130,669 Untitled14.ipynb
# 04-10-2022  11:20            14,811 Untitled2.ipynb
# 04-10-2022  11:12               711 Untitled3.ipynb
# 05-10-2022  21:35               576 Untitled4.ipynb
# 14-10-2022  00:57             1,579 Untitled5.ipynb
# 21-10-2022  23:29           172,211 Untitled6.ipynb
# 26-10-2022  17:27            15,421 Untitled7.ipynb
# 27-10-2022  00:43             1,329 Untitled8.ipynb
# 27-10-2022  19:16             2,164 Untitled9.ipynb
# 25-04-2022  08:56    <DIR>          Videos
# 26-11-2022  15:45           236,180 vocab.enron.txt
# 26-11-2022  15:45            55,467 vocab.kos.txt
# 26-11-2022  15:45           100,807 vocab.nips.txt
# 26-11-2022  15:46         1,345,665 vocab.nytimes.txt
# 26-11-2022  15:46         1,460,248 vocab.pubmed.txt
# 22-05-2021  02:02                 0 where
# 24-11-2022  18:43         3,473,784 winrar-x64-611.exe
# 06-12-2022  00:12             5,947 Working with Python MongoDB Part1 revision.ipynb
#              165 File(s)    654,158,266 bytes
#               31 Dir(s)  185,409,728,512 bytes free

# %%
len(l)
# Out:
# 3

# %%
l[0].to_csv('cricket.csv' , index = False )

# %%
l[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
l[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  New Zealand v India at Napier, 3rd T20I, Nov 2...
# 2  New Zealand v India at Mount Maunganui, 2nd T2...
# 3  England v India at Adelaide, ICC Men's T20 Wor...

# %%
d ="""{"name" : "Sudhanshu kumar" , 
"email id " : "sskumar@gmail.com",
"tech" : ["ML" , "DL" , "CV" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
type(d)
# Out:
# str

# %%
import json

# %%
result = json.loads(d)

# %%
type(result)
# Out:
# dict

# %%
result['name']
# Out:
# 'Sudhanshu kumar'

# %%
pd.DataFrame(result['tech'])
# Out:
#     0
# 0  ML
# 1  DL
# 2  CV

# %%
result['tech']
# Out:
# ['ML', 'DL', 'CV']

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
d1= d['data']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticTroubleCodeData': [],
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
del d1['diagnosticTroubleCodeData']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# 3               -0.08                0.00            -0.00008
#
#   batteryCrankParamV0  ... coolantMin coolantMax coolantAverage  \
# 0                0.00  ...     158.00     188.60         180.20
# 1                0.00  ...     158.00     188.60         180.20
# 2                0.00  ...     158.00     188.60         180.20
# 3                0.00  ...     158.00     188.60         180.20
#
#   packetStartLocal tripStartLocal milIndicator monitorsNotReady      imei  \
# 0    1508143346000  1508143346000            F                0  60DF5417
# 1    1508143346000  1508143346000            F                0  60DF5417
# 2    1508143346000  1508143346000            F                0  60DF5417
# 3    1508143346000  1508143346000            F                0  60DF5417
#
#        gatewayTs   diagnosticPidData
# 0  1515613306592    [64768, 47, 100]
# 1  1515613306592  [64768, 1, 517376]
# 2  1515613306592  [64800, 1, 262144]
# 3  1515613306592     [64768, 5, 125]
#
# [4 rows x 35 columns]

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/50088  1479738626
# 1     https://github.com/pandas-dev/pandas/pull/50087  1479661233
# 2     https://github.com/pandas-dev/pandas/pull/50085  1478990996
# 3   https://github.com/pandas-dev/pandas/issues/50083  1478407357
# 4     https://github.com/pandas-dev/pandas/pull/50082  1478075405
# 5     https://github.com/pandas-dev/pandas/pull/50081  1477974885
# 6   https://github.com/pandas-dev/pandas/issues/50080  1477971526
# 7     https://github.com/pandas-dev/pandas/pull/50079  1477942254
# 8     https://github.com/pandas-dev/pandas/pull/50078  1477797187
# 9   https://github.com/pandas-dev/pandas/issues/50076  1477486811
# 10  https://github.com/pandas-dev/pandas/issues/50074  1477413677
# 11    https://github.com/pandas-dev/pandas/pull/50073  1477314772
# 12  https://github.com/pandas-dev/pandas/issues/50072  1477297528
# 13  https://github.com/pandas-dev/pandas/issues/50071  1477293653
# 14  https://github.com/pandas-dev/pandas/issues/50069  1476970792
# 15    https://github.com/pandas-dev/pandas/pull/50068  1476853281
# 16    https://github.com/pandas-dev/pandas/pull/50067  1476825469
# 17  https://github.com/pandas-dev/pandas/issues/50066  1476733959
# 18    https://github.com/pandas-dev/pandas/pull/50065  1476366987
# 19  https://github.com/pandas-dev/pandas/issues/50062  1475421765
# 20    https://github.com/pandas-dev/pandas/pull/50061  1475268297
# 21  https://github.com/pandas-dev/pandas/issues/50059  1475085032
# 22  https://github.com/pandas-dev/pandas/issues/50058  1475026595
# 23    https://github.com/pandas-dev/pandas/pull/50056  1474962707
# 24    https://github.com/pandas-dev/pandas/pull/50054  1474871926
# 25    https://github.com/pandas-dev/pandas/pull/50053  1474804774
# 26    https://github.com/pandas-dev/pandas/pull/50052  1474739624
# 27  https://github.com/pandas-dev/pandas/issues/50051  1474732854
# 28    https://github.com/pandas-dev/pandas/pull/50050  1474729122
# 29    https://github.com/pandas-dev/pandas/pull/50049  1474446325
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD85EhHzE   50088
# 1   PR_kwDOAA0YD85Eg1-6   50087
# 2   PR_kwDOAA0YD85EedsU   50085
# 3    I_kwDOAA0YD85YHrS9   50083
# 4   PR_kwDOAA0YD85EbRpL   50082
# 5   PR_kwDOAA0YD85Ea7sj   50081
# 6    I_kwDOAA0YD85YGA5G   50080
# 7   PR_kwDOAA0YD85Ea0Xw   50079
# 8   PR_kwDOAA0YD85EaS6q   50078
# 9    I_kwDOAA0YD85YEKjb   50076
# 10   I_kwDOAA0YD85YD4st   50074
# 11  PR_kwDOAA0YD85EYloq   50073
# 12   I_kwDOAA0YD85YDcV4   50072
# 13   I_kwDOAA0YD85YDbZV   50071
# 14   I_kwDOAA0YD85YCMko   50069
# 15  PR_kwDOAA0YD85EW-C2   50068
# 16  PR_kwDOAA0YD85EW34A   50067
# 17   I_kwDOAA0YD85YBSwH   50066
# 18  PR_kwDOAA0YD85EVQ1p   50065
# 19   I_kwDOAA0YD85X8SZF   50062
# 20  PR_kwDOAA0YD85ERar1   50061
# 21   I_kwDOAA0YD85X7ALo   50059
# 22   I_kwDOAA0YD85X6x6j   50058
# 23  PR_kwDOAA0YD85EQVq9   50056
# 24  PR_kwDOAA0YD85EQBZo   50054
# 25  PR_kwDOAA0YD85EPyH7   50053
# 26  PR_kwDOAA0YD85EPjou   50052
# 27   I_kwDOAA0YD85X5qM2   50051
# 28  PR_kwDOAA0YD85EPhUg   50050
# 29  PR_kwDOAA0YD85EOg5w   50049
#
#                                                 title  ... closed_at  \
# 0                    Truncate table option for to sql  ...       NaT
# 1   BUG: SparseArray[dt64_weird_fill_value].astype...  ...       NaT
# 2   BUG: unwrap setitem indexer for 1D-only extens...  ...       NaT
# 3   Incorrect identically-labeled DataFrame object...  ...       NaT
# 4                   BUG: DatetimeArray.astype(Sparse)  ...       NaT
# 5   BUG: SeriesGroupBy.nunique raises when groupin...  ...       NaT
# 6   DOC: No example for `on` kwarg of `DataFrame.r...  ...       NaT
# 7   TST: Add test for groupby aggregatation with n...  ...       NaT
# 8   PERF: ExtensionBlock.fillna dispatch to underl...  ...       NaT
# 9   ENH: KeyError from missing column should list ...  ...       NaT
# 10  BUG: `string[pyarrow]` dtype doesn't roundtrip...  ...       NaT
# 11                             WIP: Dont double parse  ...       NaT
# 12  BUG: %Y%m%d format with errors='ignore' doesn'...  ...       NaT
# 13  BUG: inconsistent None handling for ISO and no...  ...       NaT
# 14     BUG: Handling of NaN values in complex columns  ...       NaT
# 15  REGR: memory_usage showing unnecessary FutureW...  ...       NaT
# 16        BUG: infer-objects raising for bytes Series  ...       NaT
# 17  BUG: Computing `sys.getsizeof` a DataFrame wit...  ...       NaT
# 18  BUG: loc.setitem raising when expanding empty ...  ...       NaT
# 19  BUG: AttributeError: CompileError object has n...  ...       NaT
# 20   TST: test to confirm rmod works for large series  ...       NaT
# 21            DEPR,VIS: remove custom matplotlib code  ...       NaT
# 22                        CI: pyarrow 10 broke our ci  ...       NaT
# 23  BUG: read_csv with engine pyarrow parsing mult...  ...       NaT
# 24  BUG: to_datetime with decimal number doesn't f...  ...       NaT
# 25  BUG: fix  AttributeError: CompileError object ...  ...       NaT
# 26  DEPR: remove Index._is backward_compat_public_...  ...       NaT
# 27  BUG: to_datetime with decimal number doesn't f...  ...       NaT
# 28              DOC: Add tips on where to locate test  ...       NaT
# 29  DOC: Improve groupby().ngroup() explanation fo...  ...       NaT
#
#    author_association active_lock_reason  draft  \
# 0                NONE                NaN    0.0
# 1              MEMBER                NaN    0.0
# 2         CONTRIBUTOR                NaN    0.0
# 3                NONE                NaN    NaN
# 4              MEMBER                NaN    0.0
# 5              MEMBER                NaN    0.0
# 6         CONTRIBUTOR                NaN    NaN
# 7                NONE                NaN    0.0
# 8         CONTRIBUTOR                NaN    0.0
# 9         CONTRIBUTOR                NaN    NaN
# 10        CONTRIBUTOR                NaN    NaN
# 11             MEMBER                NaN    1.0
# 12             MEMBER                NaN    NaN
# 13             MEMBER                NaN    NaN
# 14               NONE                NaN    NaN
# 15             MEMBER                NaN    0.0
# 16             MEMBER                NaN    0.0
# 17               NONE                NaN    NaN
# 18             MEMBER                NaN    0.0
# 19               NONE                NaN    NaN
# 20        CONTRIBUTOR                NaN    1.0
# 21             MEMBER                NaN    NaN
# 22             MEMBER                NaN    NaN
# 23             MEMBER                NaN    0.0
# 24             MEMBER                NaN    1.0
# 25               NONE                NaN    0.0
# 26        CONTRIBUTOR                NaN    0.0
# 27             MEMBER                NaN    NaN
# 28               NONE                NaN    0.0
# 29        CONTRIBUTOR                NaN    0.0
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3                                                 NaN
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6                                                 NaN
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9                                                 NaN
# 10                                                NaN
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17                                                NaN
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19                                                NaN
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21                                                NaN
# 22                                                NaN
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27                                                NaN
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                                  body  \
# 0   - [X] closes #37210 - in order to reload a tab...
# 1   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 2   - [ ] [Tests added and passed](https://pandas....
# 3   When we have exact same columns in source and ...
# 4   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 5   - [x] closes #21334 (Replace xxxx with the Git...
# 6   ### Pandas version checks\n\n- [X] I have chec...
# 7   - [ ] closes #25471  (Replace xxxx with the Gi...
# 8   - [x] [Tests added and passed](https://pandas....
# 9   ### Feature Type\r\n\r\n- [ ] Adding new funct...
# 10  ### Pandas version checks\n\n- [X] I have chec...
# 11  - [ ] closes #50071 (Replace xxxx with the Git...
# 12  ### Pandas version checks\r\n\r\n- [X] I have ...
# 13  ### Pandas version checks\n\n- [X] I have chec...
# 14  ### Pandas version checks\n\n- [X] I have chec...
# 15  - [x] closes #50066 (Replace xxxx with the Git...
# 16  - [x] closes #49650 (Replace xxxx with the Git...
# 17  ### Pandas version checks\n\n- [X] I have chec...
# 18  - [x] closes #49972 (Replace xxxx with the Git...
# 19  ### Pandas version checks\n\n- [X] I have chec...
# 20  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 21  ## The good - definitely keep\r\n\r\nBefore ta...
# 22  Some pyarrow tests were failing. Additionally ...
# 23  - [ ] closes #47961 (Replace xxxx with the Git...
# 24  - [x] closes #50051 (Replace xxxx with the Git...
# 25  - [x] closes #50062 (Replace xxxx with the Git...
# 26  Removes the attribute  `Index._is backward_com...
# 27  ### Pandas version checks\r\n\r\n- [X] I have ...
# 28                                      Closes #50014
# 29  The exact prose and examples are open to impro...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 0                       NaN          NaN
# 1                       NaN          NaN
# 2                       NaN          NaN
# 3                       NaN          NaN
# 4                       NaN          NaN
# 5                       NaN          NaN
# 6                       NaN          NaN
# 7                       NaN          NaN
# 8                       NaN          NaN
# 9                       NaN          NaN
# 10                      NaN          NaN
# 11                      NaN          NaN
# 12                      NaN          NaN
# 13                      NaN          NaN
# 14                      NaN          NaN
# 15                      NaN          NaN
# 16                      NaN          NaN
# 17                      NaN          NaN
# 18                      NaN          NaN
# 19                      NaN          NaN
# 20                      NaN          NaN
# 21                      NaN          NaN
# 22                      NaN          NaN
# 23                      NaN          NaN
# 24                      NaN          NaN
# 25                      NaN          NaN
# 26                      NaN          NaN
# 27                      NaN          NaN
# 28                      NaN          NaN
# 29                      NaN          NaN
#
# [30 rows x 30 columns]

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50088',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50088/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50088/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50088/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50088',
#   'id': 1479738626,
#   'node_id': 'PR_kwDOAA0YD85EhHzE',
#   'number': 50088,
#   'title': 'Truncate table option for to sql',
#   'user': {'login': 'lzieglerpenn',
#    'id': 97629580,
#    'node_id': 'U_kgDOBdG1jA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97629580?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lzieglerpenn',
#    'html_url': 'https://github.com/lzieglerpenn',
#    'followers_url': 'https://api.github.com/users/lzieglerpenn/followers',
#    'following_url': 'https://api.github.com/users/lzieglerpenn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lzieglerpenn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lzieglerpenn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lzieglerpenn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lzieglerpenn/orgs',
#    'repos_url': 'https://api.github.com/users/lzieglerpenn/repos',
#    'events_url': 'https://api.github.com/users/lzieglerpenn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lzieglerpenn/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-06T17:43:32Z',
#   'updated_at': '2022-12-06T17:43:32Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50088',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50088',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50088.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50088.patch',
#    'merged_at': None},
#   'body': '- [X] closes #37210 - in order to reload a table but not drop it to avoid CASCADE-ing\r\n- [X] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [X] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [X] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [X] Added an entry in the latest `doc/source/whatsnew/v1.5.3.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50088/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50088/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50087',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50087/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50087/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50087/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50087',
#   'id': 1479661233,
#   'node_id': 'PR_kwDOAA0YD85Eg1-6',
#   'number': 50087,
#   'title': 'BUG: SparseArray[dt64_weird_fill_value].astype(int64)',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-06T17:12:20Z',
#   'updated_at': '2022-12-06T17:13:18Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50087',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50087',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50087.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50087.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50087/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50087/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50085',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50085/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50085/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50085/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50085',
#   'id': 1478990996,
#   'node_id': 'PR_kwDOAA0YD85EedsU',
#   'number': 50085,
#   'title': 'BUG: unwrap setitem indexer for 1D-only extension arrays',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-06T12:31:43Z',
#   'updated_at': '2022-12-06T17:20:39Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50085',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50085',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50085.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50085.patch',
#    'merged_at': None},
#   'body': '- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.0.0.rst` file if fixing a bug or adding a new feature.\r\n\r\nSetting values in a pyarrow-backed column with a non-scalar indexer was raising. \r\n\r\nFixes the following:\r\n\r\n```\r\nimport pandas as pd\r\n\r\ndf = pd.DataFrame({"a": [1, 2, 3], "b": [4, 5, 6]}, dtype="int64[pyarrow]")\r\n\r\n# IndexError: index 1 is out of bounds for axis 0 with size 1\r\ndf.loc[[0, 1], "b"] = 0\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50085/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50085/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50083',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50083/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50083/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50083/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50083',
#   'id': 1478407357,
#   'node_id': 'I_kwDOAA0YD85YHrS9',
#   'number': 50083,
#   'title': 'Incorrect identically-labeled DataFrame objects Exception comes with df.compare method ',
#   'user': {'login': 'abhid001',
#    'id': 47380596,
#    'node_id': 'MDQ6VXNlcjQ3MzgwNTk2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47380596?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/abhid001',
#    'html_url': 'https://github.com/abhid001',
#    'followers_url': 'https://api.github.com/users/abhid001/followers',
#    'following_url': 'https://api.github.com/users/abhid001/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/abhid001/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/abhid001/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/abhid001/subscriptions',
#    'organizations_url': 'https://api.github.com/users/abhid001/orgs',
#    'repos_url': 'https://api.github.com/users/abhid001/repos',
#    'events_url': 'https://api.github.com/users/abhid001/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/abhid001/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-06T07:05:20Z',
#   'updated_at': '2022-12-06T07:06:47Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': 'When we have exact same columns in source and target dataframes and distinct number of rows then we are seeing below exception which according to me is misleading.\r\n\r\n"**ValueError: Can only compare identically-labeled DataFrame objects**"\r\n\r\n#CODE :\r\n\r\n```import pandas as pd\r\n#define DataFrames\r\ndf1 = pd.DataFrame({\'points\': [25, 12, 15, 14],\r\n                   \'assists\': [5, 7, 13, 12]})\r\n\r\ndf2 = pd.DataFrame({\'points\': [25, 12, 15],\r\n                    \'assists\': [5, 7, 13]})\r\n\r\nprint(df1)\r\n\r\n   points  assists\r\n0      25        5\r\n1      12        7\r\n2      15       13\r\n3      14       12\r\n\r\nprint(df2)\r\n\r\n   points  assists\r\n0      25        5\r\n1      12        7\r\n2      15       13\r\n\r\n# Compare both dataframes\r\n\r\ndf1.compare(df2)\r\n\r\n+++++++++++++++++++++++++++++++++ERROR+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\r\nTraceback (most recent call last):\r\n  File "<input>", line 1, in <module>\r\n  File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py", line 7117, in compare\r\n    keep_equal=keep_equal,\r\n  File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py", line 8424, in compare\r\n    mask = ~((self == other) | (self.isna() & other.isna()))\r\n  File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/ops/common.py", line 69, in new_method\r\n    return method(self, other)\r\n  File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/arraylike.py", line 32, in __eq__\r\n    return self._cmp_method(other, operator.eq)\r\n  File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py", line 6851, in _cmp_method\r\n    self, other = ops.align_method_FRAME(self, other, axis, flex=False, level=None)\r\n  File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/ops/__init__.py", line 289, in align_method_FRAME\r\n    "Can only compare identically-labeled DataFrame objects"\r\nValueError: Can only compare identically-labeled DataFrame objects\r\n+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50083/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50083/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50082',
#   'id': 1478075405,
#   'node_id': 'PR_kwDOAA0YD85EbRpL',
#   'number': 50082,
#   'title': 'BUG: DatetimeArray.astype(Sparse)',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-06T03:26:10Z',
#   'updated_at': '2022-12-06T03:26:57Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50082',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50082',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50082.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50082.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50081',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50081/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50081/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50081/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50081',
#   'id': 1477974885,
#   'node_id': 'PR_kwDOAA0YD85Ea7sj',
#   'number': 50081,
#   'title': 'BUG: SeriesGroupBy.nunique raises when grouping with an empty categrorical',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 78527356,
#     'node_id': 'MDU6TGFiZWw3ODUyNzM1Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Categorical',
#     'name': 'Categorical',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Categorical Data Type'},
#    {'id': 2365504383,
#     'node_id': 'MDU6TGFiZWwyMzY1NTA0Mzgz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reduction%20Operations',
#     'name': 'Reduction Operations',
#     'color': '547c03',
#     'default': False,
#     'description': 'sum, mean, min, max, etc.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/42',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42/labels',
#    'id': 1945020,
#    'node_id': 'MDk6TWlsZXN0b25lMTk0NTAyMA==',
#    'number': 42,
#    'title': '2.0',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 44,
#    'closed_issues': 729,
#    'state': 'open',
#    'created_at': '2016-08-16T13:21:24Z',
#    'updated_at': '2022-12-06T17:51:18Z',
#    'due_on': '2022-12-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-12-06T02:19:19Z',
#   'updated_at': '2022-12-06T02:19:26Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50081',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50081',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50081.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50081.patch',
#    'merged_at': None},
#   'body': '- [x] closes #21334 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50081/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50081/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50080',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50080/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50080/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50080/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50080',
#   'id': 1477971526,
#   'node_id': 'I_kwDOAA0YD85YGA5G',
#   'number': 50080,
#   'title': 'DOC: No example for `on` kwarg of `DataFrame.rolling()`',
#   'user': {'login': 'janosh',
#    'id': 30958850,
#    'node_id': 'MDQ6VXNlcjMwOTU4ODUw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30958850?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/janosh',
#    'html_url': 'https://github.com/janosh',
#    'followers_url': 'https://api.github.com/users/janosh/followers',
#    'following_url': 'https://api.github.com/users/janosh/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/janosh/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/janosh/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/janosh/subscriptions',
#    'organizations_url': 'https://api.github.com/users/janosh/orgs',
#    'repos_url': 'https://api.github.com/users/janosh/repos',
#    'events_url': 'https://api.github.com/users/janosh/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/janosh/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1045950827,
#     'node_id': 'MDU6TGFiZWwxMDQ1OTUwODI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Window',
#     'name': 'Window',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': 'rolling, ewma, expanding'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-06T02:16:11Z',
#   'updated_at': '2022-12-06T17:07:29Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\nhttps://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rolling.html\n\n### Documentation problem\n\nThere are 11 examples for [`DataFrame.rolling()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rolling.html) but none show or explain the effect of setting `on` to a column name.\n\n### Suggested fix for documentation\n\nAdd `on` example. Sth like\r\n\r\n```py\r\ndf = pd.util.testing.makeDataFrame()\r\n\r\ndf.rolling(window=4, on='A').mean()\r\n```\r\n\r\ngives the same output as `df.rolling(window=4).mean()` which is why I'm unclear what effect `on` should have.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50080/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50080/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50079',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50079/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50079/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50079/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50079',
#   'id': 1477942254,
#   'node_id': 'PR_kwDOAA0YD85Ea0Xw',
#   'number': 50079,
#   'title': 'TST: Add test for groupby aggregatation with nested dictionary',
#   'user': {'login': 'talukder-sowrov',
#    'id': 42917737,
#    'node_id': 'MDQ6VXNlcjQyOTE3NzM3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42917737?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/talukder-sowrov',
#    'html_url': 'https://github.com/talukder-sowrov',
#    'followers_url': 'https://api.github.com/users/talukder-sowrov/followers',
#    'following_url': 'https://api.github.com/users/talukder-sowrov/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/talukder-sowrov/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/talukder-sowrov/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/talukder-sowrov/subscriptions',
#    'organizations_url': 'https://api.github.com/users/talukder-sowrov/orgs',
#    'repos_url': 'https://api.github.com/users/talukder-sowrov/repos',
#    'events_url': 'https://api.github.com/users/talukder-sowrov/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/talukder-sowrov/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-06T01:52:23Z',
#   'updated_at': '2022-12-06T01:52:23Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50079',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50079',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50079.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50079.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #25471  (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50079/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50079/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50078',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50078/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50078/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50078/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50078',
#   'id': 1477797187,
#   'node_id': 'PR_kwDOAA0YD85EaS6q',
#   'number': 50078,
#   'title': 'PERF: ExtensionBlock.fillna dispatch to underlying arrays',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 849023693,
#     'node_id': 'MDU6TGFiZWw4NDkwMjM2OTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/ExtensionArray',
#     'name': 'ExtensionArray',
#     'color': '6138b5',
#     'default': False,
#     'description': 'Extending pandas with custom dtypes or arrays.'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-12-06T00:26:36Z',
#   'updated_at': '2022-12-06T03:25:29Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50078',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50078',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50078.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50078.patch',
#    'merged_at': None},
#   'body': "- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.0.0.rst` file if fixing a bug or adding a new feature.\r\n\r\nPer discussion: https://github.com/pandas-dev/pandas/pull/49722#issuecomment-1337974871\r\n\r\nThe discussion focused on pyarrow-backed dtypes, but it seems there is an improvement for other extension types as well:\r\n\r\n```\r\n       before           after         ratio\r\n     [1c71d7db]       [86e52fee]\r\n     <main>           <extensionblock-fillna>\r\n-      8.08±0.2ms       6.72±0.1ms     0.83  series_methods.Fillna.time_fillna('Int64', None)\r\n-      8.26±0.2ms      6.85±0.07ms     0.83  series_methods.Fillna.time_fillna('Float64', None)\r\n-         128±3ms         72.3±2ms     0.56  series_methods.Fillna.time_fillna('string', None)\r\n-      15.1±0.6ms      5.41±0.04ms     0.36  series_methods.Fillna.time_fillna('int64[pyarrow]', None)\r\n-      60.7±0.6ms      4.82±0.02ms     0.08  series_methods.Fillna.time_fillna('string[pyarrow]', None)\r\n```",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50078/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50078/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50076',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50076/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50076/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50076/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50076',
#   'id': 1477486811,
#   'node_id': 'I_kwDOAA0YD85YEKjb',
#   'number': 50076,
#   'title': 'ENH: KeyError from missing column should list available columns',
#   'user': {'login': 'janosh',
#    'id': 30958850,
#    'node_id': 'MDQ6VXNlcjMwOTU4ODUw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30958850?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/janosh',
#    'html_url': 'https://github.com/janosh',
#    'followers_url': 'https://api.github.com/users/janosh/followers',
#    'following_url': 'https://api.github.com/users/janosh/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/janosh/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/janosh/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/janosh/subscriptions',
#    'organizations_url': 'https://api.github.com/users/janosh/orgs',
#    'repos_url': 'https://api.github.com/users/janosh/repos',
#    'events_url': 'https://api.github.com/users/janosh/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/janosh/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 42670965,
#     'node_id': 'MDU6TGFiZWw0MjY3MDk2NQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Error%20Reporting',
#     'name': 'Error Reporting',
#     'color': 'ffa0ff',
#     'default': False,
#     'description': 'Incorrect or improved errors from pandas'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-12-05T21:36:31Z',
#   'updated_at': '2022-12-05T23:36:35Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Feature Type\r\n\r\n- [ ] Adding new functionality to pandas\r\n\r\n- [X] Changing existing functionality in pandas\r\n\r\n- [ ] Removing existing functionality in pandas\r\n\r\n\r\n### Problem Description\r\n\r\n```py\r\nimport pandas as pd\r\n\r\ndf = pd.util.testing.makeMixedDataFrame()\r\n\r\nprint(f\'{list(df)=}\')\r\n>>> list(df)=[\'A\', \'B\', \'C\', \'D\']\r\n\r\ndf[[\'foo\']]\r\n>>> KeyError: "[\'foo\'] not in index"\r\n```\r\n\r\n\r\n### Feature Description\r\n\r\nThe error message would be more helpful if it listed available columns:\r\n\r\n```py\r\ndf[[\'foo\']]\r\n>>> KeyError: "[\'foo\'] not in columns=[\'A\', \'B\', \'C\', \'D\']"\r\n```\r\n\r\n### Alternative Solutions\r\n\r\nn/a\r\n\r\n### Additional Context\r\n\r\n_No response_',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50076/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50076/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50074',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50074/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50074/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50074/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50074',
#   'id': 1477413677,
#   'node_id': 'I_kwDOAA0YD85YD4st',
#   'number': 50074,
#   'title': "BUG: `string[pyarrow]` dtype doesn't roundtrip through `pyarrow`",
#   'user': {'login': 'jrbourbeau',
#    'id': 11656932,
#    'node_id': 'MDQ6VXNlcjExNjU2OTMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11656932?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jrbourbeau',
#    'html_url': 'https://github.com/jrbourbeau',
#    'followers_url': 'https://api.github.com/users/jrbourbeau/followers',
#    'following_url': 'https://api.github.com/users/jrbourbeau/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jrbourbeau/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jrbourbeau/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jrbourbeau/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jrbourbeau/orgs',
#    'repos_url': 'https://api.github.com/users/jrbourbeau/repos',
#    'events_url': 'https://api.github.com/users/jrbourbeau/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jrbourbeau/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 57522093,
#     'node_id': 'MDU6TGFiZWw1NzUyMjA5Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Strings',
#     'name': 'Strings',
#     'color': '5319e7',
#     'default': False,
#     'description': 'String extension data type and string data'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 5,
#   'created_at': '2022-12-05T20:49:58Z',
#   'updated_at': '2022-12-06T18:02:04Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nimport pyarrow as pa\r\n\r\ndf = pd.DataFrame({"x": ["foo", "bar", "baz"]}, dtype="string[pyarrow]")\r\n# Round-trip `df` through pyarrow using `Table.from_pandas` and `Table_to_pandas` + `types_mapper=`\r\ntypes_mapper={pa.string(): pd.ArrowDtype(pa.string())}\r\ndf_pa = pa.Table.from_pandas(df).to_pandas(types_mapper=types_mapper.get)\r\npd.testing.assert_frame_equal(df, df_pa)\r\n# The assertion above fails with:\r\n# Attribute "dtype" are different\r\n# [left]:  string[pyarrow]\r\n# [right]: string[pyarrow]\n```\n\n\n### Issue Description\n\nWhile working on improved support for `pyarrow`-backed dtypes over in Dask, I came across a case where round-tripping a DataFrame with `string[pyarrow]` dtypes doesn\'t appear to fully work as expected. \n\n### Expected Behavior\n\nWhen using `pa.Table.from_pandas` and `pa.Table.to_pandas` + `types_mapper` as described in the above example, I would expect to get an equivalent DataFrame back. \r\n\r\nAdditionally, the \r\n\r\n```\r\nAttribute "dtype" are different\r\n[left]:  string[pyarrow]\r\n[right]: string[pyarrow]\r\n```\r\n\r\nis somewhat confusing as, from the information in the error message, it actually looks like these dtypes should be the same. \r\n\n\n### Installed Versions\n\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 8dab54d6573f7186ff0c3b6364d5e4dd635ff3e7\r\npython           : 3.9.15.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 21.6.0\r\nVersion          : Darwin Kernel Version 21.6.0: Thu Sep 29 20:12:57 PDT 2022; root:xnu-8020.240.7~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.2\r\nnumpy            : 1.21.6\r\npytz             : 2022.6\r\ndateutil         : 2.8.2\r\nsetuptools       : 59.8.0\r\npip              : 22.3.1\r\nCython           : None\r\npytest           : 7.2.0\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.7.0\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : None\r\nbrotli           :\r\nfastparquet      : 2022.11.0\r\nfsspec           : 2022.11.0\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : 0.56.4\r\nnumexpr          : 2.8.3\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 10.0.1\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : 2022.11.0\r\nscipy            : 1.9.3\r\nsnappy           :\r\nsqlalchemy       : 1.4.44\r\ntables           : 3.7.0\r\ntabulate         : None\r\nxarray           : 2022.11.0\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n```\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50074/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50074/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50073',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50073/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50073/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50073/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50073',
#   'id': 1477314772,
#   'node_id': 'PR_kwDOAA0YD85EYloq',
#   'number': 50073,
#   'title': 'WIP: Dont double parse',
# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50053/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50053/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50052',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50052/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50052/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50052/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50052',
#   'id': 1474739624,
#   'node_id': 'PR_kwDOAA0YD85EPjou',
#   'number': 50052,
#   'title': 'DEPR: remove Index._is backward_compat_public_numeric_index',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-04T11:43:44Z',
#   'updated_at': '2022-12-05T23:53:13Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50052',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50052',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50052.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50052.patch',
#    'merged_at': None},
#   'body': "Removes the attribute  `Index._is backward_compat_public_numeric_index`and related stuff. This is the last PR before actually removing Int64/UInt64/Float64Index from the code base.\r\n\r\nThis PR builds on top of #49560 (which is not yet merged), so please exclude the first commit  from review of this PR.\r\n\r\nI'd also truly appreciate if someone could review #49560, as it's quite a heavy PR with lots of dtype changes.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50052/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50052/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50051',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50051/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50051/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50051/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50051',
#   'id': 1474732854,
#   'node_id': 'I_kwDOAA0YD85X5qM2',
#   'number': 50051,
#   'title': "BUG: to_datetime with decimal number doesn't fail for %Y%m%d",
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2022-12-04T11:34:07Z',
#   'updated_at': '2022-12-04T18:30:52Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nto_datetime(['19801212.0'], format='%Y%m%d', exact=True)\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nThis should fail, there's no interpretation of  `format` in which `19801212.0` matches `%Y%m%d`\r\n\r\n### Expected Behavior\r\n\r\nProbably something like\r\n```\r\nValueError: unconverted data remains: .0\r\n```\r\nbut certainly not that it passes without an error\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 732ad9f281bf6efffa12b8a872df98e18c11e3b7\r\npython           : 3.8.15.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.10.102.1-microsoft-standard-WSL2\r\nVersion          : #1 SMP Wed Mar 2 00:30:59 UTC 2022\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_GB.UTF-8\r\nLOCALE           : en_GB.UTF-8\r\n\r\npandas           : 2.0.0.dev0+838.g732ad9f281.dirty\r\nnumpy            : 1.23.5\r\npytz             : 2022.6\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.5.1\r\npip              : 22.3.1\r\nCython           : 0.29.32\r\npytest           : 7.2.0\r\nhypothesis       : 6.59.0\r\nsphinx           : 4.5.0\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 3.0.3\r\nlxml.etree       : 4.9.1\r\nhtml5lib         : 1.1\r\npymysql          : 1.0.2\r\npsycopg2         : 2.9.3\r\njinja2           : 3.0.3\r\nIPython          : 8.7.0\r\npandas_datareader: 0.10.0\r\nbs4              : 4.11.1\r\nbottleneck       : 1.3.5\r\nbrotli           : \r\nfastparquet      : 2022.11.0\r\nfsspec           : 2021.11.0\r\ngcsfs            : 2021.11.0\r\nmatplotlib       : 3.6.2\r\nnumba            : 0.56.4\r\nnumexpr          : 2.8.3\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : 0.17.9\r\npyarrow          : 9.0.0\r\npyreadstat       : 1.2.0\r\npyxlsb           : 1.0.10\r\ns3fs             : 2021.11.0\r\nscipy            : 1.9.3\r\nsnappy           : \r\nsqlalchemy       : 1.4.44\r\ntables           : 3.7.0\r\ntabulate         : 0.9.0\r\nxarray           : 2022.11.0\r\nxlrd             : 2.0.1\r\nzstandard        : 0.19.0\r\ntzdata           : None\r\nqtpy             : None\r\npyqt5            : None\r\nNone\r\n\r\n\r\n</details>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50051/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50051/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50050',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50050/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50050/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50050/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50050',
#   'id': 1474729122,
#   'node_id': 'PR_kwDOAA0YD85EPhUg',
#   'number': 50050,
#   'title': 'DOC: Add tips on where to locate test',
#   'user': {'login': 'georgemunyoro',
#    'id': 32019551,
#    'node_id': 'MDQ6VXNlcjMyMDE5NTUx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32019551?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/georgemunyoro',
#    'html_url': 'https://github.com/georgemunyoro',
#    'followers_url': 'https://api.github.com/users/georgemunyoro/followers',
#    'following_url': 'https://api.github.com/users/georgemunyoro/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/georgemunyoro/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/georgemunyoro/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/georgemunyoro/subscriptions',
#    'organizations_url': 'https://api.github.com/users/georgemunyoro/orgs',
#    'repos_url': 'https://api.github.com/users/georgemunyoro/repos',
#    'events_url': 'https://api.github.com/users/georgemunyoro/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/georgemunyoro/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-12-04T11:28:45Z',
#   'updated_at': '2022-12-06T10:40:32Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50050',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50050',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50050.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50050.patch',
#    'merged_at': None},
#   'body': 'Closes #50014',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50050/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50050/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50049',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50049/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50049/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50049/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50049',
#   'id': 1474446325,
#   'node_id': 'PR_kwDOAA0YD85EOg5w',
#   'number': 50049,
#   'title': 'DOC: Improve groupby().ngroup() explanation for missing groups',
#   'user': {'login': 'NickCrews',
#    'id': 10820686,
#    'node_id': 'MDQ6VXNlcjEwODIwNjg2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10820686?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NickCrews',
#    'html_url': 'https://github.com/NickCrews',
#    'followers_url': 'https://api.github.com/users/NickCrews/followers',
#    'following_url': 'https://api.github.com/users/NickCrews/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/NickCrews/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/NickCrews/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/NickCrews/subscriptions',
#    'organizations_url': 'https://api.github.com/users/NickCrews/orgs',
#    'repos_url': 'https://api.github.com/users/NickCrews/repos',
#    'events_url': 'https://api.github.com/users/NickCrews/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/NickCrews/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-04T04:43:20Z',
#   'updated_at': '2022-12-05T23:56:29Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50049',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50049',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50049.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50049.patch',
#    'merged_at': None},
#   'body': "The exact prose and examples are open to improvements if you have ideas.\n\nI figure this didn't require a separate issue, please let me know if I'm missing some step in the process.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50049/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50049/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
len(data1)
# Out:
# 30

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 97629580
# 8078968
# 8519523
# 47380596
# 8078968
# 45562402
# 30958850
# 42917737
# 8519523
# 30958850
# 11656932
# 33491632
# 33491632
# 33491632
# 19598248
# 61934744
# 61934744
# 40615374
# 61934744
# 28446653
# 116989963
# 33491632
# 61934744
# 47963215
# 33491632
# 28446653
# 26364415
# 33491632
# 32019551
# 10820686

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50088',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50088/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50088/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50088/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50088',
#   'id': 1479738626,
#   'node_id': 'PR_kwDOAA0YD85EhHzE',
#   'number': 50088,
#   'title': 'Truncate table option for to sql',
#   'user': {'login': 'lzieglerpenn',
#    'id': 97629580,
#    'node_id': 'U_kgDOBdG1jA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97629580?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lzieglerpenn',
#    'html_url': 'https://github.com/lzieglerpenn',
#    'followers_url': 'https://api.github.com/users/lzieglerpenn/followers',
#    'following_url': 'https://api.github.com/users/lzieglerpenn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lzieglerpenn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lzieglerpenn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lzieglerpenn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lzieglerpenn/orgs',
#    'repos_url': 'https://api.github.com/users/lzieglerpenn/repos',
#    'events_url': 'https://api.github.com/users/lzieglerpenn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lzieglerpenn/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-06T17:43:32Z',
#   'updated_at': '2022-12-06T17:43:32Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50088',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50088',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50088.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50088.patch',
#    'merged_at': None},
#   'body': '- [X] closes #37210 - in order to reload a table but not drop it to avoid CASCADE-ing\r\n- [X] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [X] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [X] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [X] Added an entry in the latest `doc/source/whatsnew/v1.5.3.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50088/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50088/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50087',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50087/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50087/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50087/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50087',
#   'id': 1479661233,
#   'node_id': 'PR_kwDOAA0YD85Eg1-6',
#   'number': 50087,
#   'title': 'BUG: SparseArray[dt64_weird_fill_value].astype(int64)',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-06T17:12:20Z',
#   'updated_at': '2022-12-06T17:13:18Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50087',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50087',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50087.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50087.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50087/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50087/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50085',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50085/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50085/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50085/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50085',
#   'id': 1478990996,
#   'node_id': 'PR_kwDOAA0YD85EedsU',
#   'number': 50085,
#   'title': 'BUG: unwrap setitem indexer for 1D-only extension arrays',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-06T12:31:43Z',
#   'updated_at': '2022-12-06T17:20:39Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50085',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50085',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50085.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50085.patch',
#    'merged_at': None},
#   'body': '- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.0.0.rst` file if fixing a bug or adding a new feature.\r\n\r\nSetting values in a pyarrow-backed column with a non-scalar indexer was raising. \r\n\r\nFixes the following:\r\n\r\n```\r\nimport pandas as pd\r\n\r\ndf = pd.DataFrame({"a": [1, 2, 3], "b": [4, 5, 6]}, dtype="int64[pyarrow]")\r\n\r\n# IndexError: index 1 is out of bounds for axis 0 with size 1\r\ndf.loc[[0, 1], "b"] = 0\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50085/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50085/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50083',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50083/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50083/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50083/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50083',
#   'id': 1478407357,
#   'node_id': 'I_kwDOAA0YD85YHrS9',
#   'number': 50083,
#   'title': 'Incorrect identically-labeled DataFrame objects Exception comes with df.compare method ',
#   'user': {'login': 'abhid001',
#    'id': 47380596,
#    'node_id': 'MDQ6VXNlcjQ3MzgwNTk2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47380596?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/abhid001',
#    'html_url': 'https://github.com/abhid001',
#    'followers_url': 'https://api.github.com/users/abhid001/followers',
#    'following_url': 'https://api.github.com/users/abhid001/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/abhid001/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/abhid001/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/abhid001/subscriptions',
#    'organizations_url': 'https://api.github.com/users/abhid001/orgs',
#    'repos_url': 'https://api.github.com/users/abhid001/repos',
#    'events_url': 'https://api.github.com/users/abhid001/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/abhid001/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-06T07:05:20Z',
#   'updated_at': '2022-12-06T07:06:47Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': 'When we have exact same columns in source and target dataframes and distinct number of rows then we are seeing below exception which according to me is misleading.\r\n\r\n"**ValueError: Can only compare identically-labeled DataFrame objects**"\r\n\r\n#CODE :\r\n\r\n```import pandas as pd\r\n#define DataFrames\r\ndf1 = pd.DataFrame({\'points\': [25, 12, 15, 14],\r\n                   \'assists\': [5, 7, 13, 12]})\r\n\r\ndf2 = pd.DataFrame({\'points\': [25, 12, 15],\r\n                    \'assists\': [5, 7, 13]})\r\n\r\nprint(df1)\r\n\r\n   points  assists\r\n0      25        5\r\n1      12        7\r\n2      15       13\r\n3      14       12\r\n\r\nprint(df2)\r\n\r\n   points  assists\r\n0      25        5\r\n1      12        7\r\n2      15       13\r\n\r\n# Compare both dataframes\r\n\r\ndf1.compare(df2)\r\n\r\n+++++++++++++++++++++++++++++++++ERROR+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\r\nTraceback (most recent call last):\r\n  File "<input>", line 1, in <module>\r\n  File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py", line 7117, in compare\r\n    keep_equal=keep_equal,\r\n  File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py", line 8424, in compare\r\n    mask = ~((self == other) | (self.isna() & other.isna()))\r\n  File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/ops/common.py", line 69, in new_method\r\n    return method(self, other)\r\n  File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/arraylike.py", line 32, in __eq__\r\n    return self._cmp_method(other, operator.eq)\r\n  File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py", line 6851, in _cmp_method\r\n    self, other = ops.align_method_FRAME(self, other, axis, flex=False, level=None)\r\n  File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/ops/__init__.py", line 289, in align_method_FRAME\r\n    "Can only compare identically-labeled DataFrame objects"\r\nValueError: Can only compare identically-labeled DataFrame objects\r\n+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50083/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50083/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50082',
#   'id': 1478075405,
#   'node_id': 'PR_kwDOAA0YD85EbRpL',
#   'number': 50082,
#   'title': 'BUG: DatetimeArray.astype(Sparse)',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-06T03:26:10Z',
#   'updated_at': '2022-12-06T03:26:57Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50082',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50082',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50082.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50082.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50081',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50081/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50081/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50081/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50081',
#   'id': 1477974885,
#   'node_id': 'PR_kwDOAA0YD85Ea7sj',
#   'number': 50081,
#   'title': 'BUG: SeriesGroupBy.nunique raises when grouping with an empty categrorical',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 78527356,
#     'node_id': 'MDU6TGFiZWw3ODUyNzM1Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Categorical',
#     'name': 'Categorical',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Categorical Data Type'},
#    {'id': 2365504383,
#     'node_id': 'MDU6TGFiZWwyMzY1NTA0Mzgz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reduction%20Operations',
#     'name': 'Reduction Operations',
#     'color': '547c03',
#     'default': False,
#     'description': 'sum, mean, min, max, etc.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/42',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42/labels',
#    'id': 1945020,
#    'node_id': 'MDk6TWlsZXN0b25lMTk0NTAyMA==',
#    'number': 42,
#    'title': '2.0',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 44,
#    'closed_issues': 729,
#    'state': 'open',
#    'created_at': '2016-08-16T13:21:24Z',
#    'updated_at': '2022-12-06T17:51:18Z',
#    'due_on': '2022-12-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-12-06T02:19:19Z',
#   'updated_at': '2022-12-06T02:19:26Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50081',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50081',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50081.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50081.patch',
#    'merged_at': None},
#   'body': '- [x] closes #21334 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50081/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50081/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50080',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50080/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50080/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50080/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50080',
#   'id': 1477971526,
#   'node_id': 'I_kwDOAA0YD85YGA5G',
#   'number': 50080,
#   'title': 'DOC: No example for `on` kwarg of `DataFrame.rolling()`',
#   'user': {'login': 'janosh',
#    'id': 30958850,
#    'node_id': 'MDQ6VXNlcjMwOTU4ODUw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30958850?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/janosh',
#    'html_url': 'https://github.com/janosh',
#    'followers_url': 'https://api.github.com/users/janosh/followers',
#    'following_url': 'https://api.github.com/users/janosh/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/janosh/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/janosh/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/janosh/subscriptions',
#    'organizations_url': 'https://api.github.com/users/janosh/orgs',
#    'repos_url': 'https://api.github.com/users/janosh/repos',
#    'events_url': 'https://api.github.com/users/janosh/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/janosh/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1045950827,
#     'node_id': 'MDU6TGFiZWwxMDQ1OTUwODI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Window',
#     'name': 'Window',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': 'rolling, ewma, expanding'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-06T02:16:11Z',
#   'updated_at': '2022-12-06T17:07:29Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\nhttps://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rolling.html\n\n### Documentation problem\n\nThere are 11 examples for [`DataFrame.rolling()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rolling.html) but none show or explain the effect of setting `on` to a column name.\n\n### Suggested fix for documentation\n\nAdd `on` example. Sth like\r\n\r\n```py\r\ndf = pd.util.testing.makeDataFrame()\r\n\r\ndf.rolling(window=4, on='A').mean()\r\n```\r\n\r\ngives the same output as `df.rolling(window=4).mean()` which is why I'm unclear what effect `on` should have.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50080/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50080/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50079',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50079/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50079/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50079/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50079',
#   'id': 1477942254,
#   'node_id': 'PR_kwDOAA0YD85Ea0Xw',
#   'number': 50079,
#   'title': 'TST: Add test for groupby aggregatation with nested dictionary',
#   'user': {'login': 'talukder-sowrov',
#    'id': 42917737,
#    'node_id': 'MDQ6VXNlcjQyOTE3NzM3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42917737?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/talukder-sowrov',
#    'html_url': 'https://github.com/talukder-sowrov',
#    'followers_url': 'https://api.github.com/users/talukder-sowrov/followers',
#    'following_url': 'https://api.github.com/users/talukder-sowrov/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/talukder-sowrov/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/talukder-sowrov/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/talukder-sowrov/subscriptions',
#    'organizations_url': 'https://api.github.com/users/talukder-sowrov/orgs',
#    'repos_url': 'https://api.github.com/users/talukder-sowrov/repos',
#    'events_url': 'https://api.github.com/users/talukder-sowrov/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/talukder-sowrov/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-06T01:52:23Z',
#   'updated_at': '2022-12-06T01:52:23Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50079',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50079',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50079.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50079.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #25471  (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50079/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50079/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50078',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50078/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50078/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50078/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50078',
#   'id': 1477797187,
#   'node_id': 'PR_kwDOAA0YD85EaS6q',
#   'number': 50078,
#   'title': 'PERF: ExtensionBlock.fillna dispatch to underlying arrays',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 849023693,
#     'node_id': 'MDU6TGFiZWw4NDkwMjM2OTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/ExtensionArray',
#     'name': 'ExtensionArray',
#     'color': '6138b5',
#     'default': False,
#     'description': 'Extending pandas with custom dtypes or arrays.'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-12-06T00:26:36Z',
#   'updated_at': '2022-12-06T03:25:29Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50078',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50078',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50078.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50078.patch',
#    'merged_at': None},
#   'body': "- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.0.0.rst` file if fixing a bug or adding a new feature.\r\n\r\nPer discussion: https://github.com/pandas-dev/pandas/pull/49722#issuecomment-1337974871\r\n\r\nThe discussion focused on pyarrow-backed dtypes, but it seems there is an improvement for other extension types as well:\r\n\r\n```\r\n       before           after         ratio\r\n     [1c71d7db]       [86e52fee]\r\n     <main>           <extensionblock-fillna>\r\n-      8.08±0.2ms       6.72±0.1ms     0.83  series_methods.Fillna.time_fillna('Int64', None)\r\n-      8.26±0.2ms      6.85±0.07ms     0.83  series_methods.Fillna.time_fillna('Float64', None)\r\n-         128±3ms         72.3±2ms     0.56  series_methods.Fillna.time_fillna('string', None)\r\n-      15.1±0.6ms      5.41±0.04ms     0.36  series_methods.Fillna.time_fillna('int64[pyarrow]', None)\r\n-      60.7±0.6ms      4.82±0.02ms     0.08  series_methods.Fillna.time_fillna('string[pyarrow]', None)\r\n```",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50078/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50078/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50076',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50076/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50076/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50076/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50076',
#   'id': 1477486811,
#   'node_id': 'I_kwDOAA0YD85YEKjb',
#   'number': 50076,
#   'title': 'ENH: KeyError from missing column should list available columns',
#   'user': {'login': 'janosh',
#    'id': 30958850,
#    'node_id': 'MDQ6VXNlcjMwOTU4ODUw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30958850?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/janosh',
#    'html_url': 'https://github.com/janosh',
#    'followers_url': 'https://api.github.com/users/janosh/followers',
#    'following_url': 'https://api.github.com/users/janosh/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/janosh/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/janosh/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/janosh/subscriptions',
#    'organizations_url': 'https://api.github.com/users/janosh/orgs',
#    'repos_url': 'https://api.github.com/users/janosh/repos',
#    'events_url': 'https://api.github.com/users/janosh/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/janosh/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 42670965,
#     'node_id': 'MDU6TGFiZWw0MjY3MDk2NQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Error%20Reporting',
#     'name': 'Error Reporting',
#     'color': 'ffa0ff',
#     'default': False,
#     'description': 'Incorrect or improved errors from pandas'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-12-05T21:36:31Z',
#   'updated_at': '2022-12-05T23:36:35Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Feature Type\r\n\r\n- [ ] Adding new functionality to pandas\r\n\r\n- [X] Changing existing functionality in pandas\r\n\r\n- [ ] Removing existing functionality in pandas\r\n\r\n\r\n### Problem Description\r\n\r\n```py\r\nimport pandas as pd\r\n\r\ndf = pd.util.testing.makeMixedDataFrame()\r\n\r\nprint(f\'{list(df)=}\')\r\n>>> list(df)=[\'A\', \'B\', \'C\', \'D\']\r\n\r\ndf[[\'foo\']]\r\n>>> KeyError: "[\'foo\'] not in index"\r\n```\r\n\r\n\r\n### Feature Description\r\n\r\nThe error message would be more helpful if it listed available columns:\r\n\r\n```py\r\ndf[[\'foo\']]\r\n>>> KeyError: "[\'foo\'] not in columns=[\'A\', \'B\', \'C\', \'D\']"\r\n```\r\n\r\n### Alternative Solutions\r\n\r\nn/a\r\n\r\n### Additional Context\r\n\r\n_No response_',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50076/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50076/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50074',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50074/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50074/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50074/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50074',
#   'id': 1477413677,
#   'node_id': 'I_kwDOAA0YD85YD4st',
#   'number': 50074,
#   'title': "BUG: `string[pyarrow]` dtype doesn't roundtrip through `pyarrow`",
#   'user': {'login': 'jrbourbeau',
#    'id': 11656932,
#    'node_id': 'MDQ6VXNlcjExNjU2OTMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11656932?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jrbourbeau',
#    'html_url': 'https://github.com/jrbourbeau',
#    'followers_url': 'https://api.github.com/users/jrbourbeau/followers',
#    'following_url': 'https://api.github.com/users/jrbourbeau/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jrbourbeau/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jrbourbeau/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jrbourbeau/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jrbourbeau/orgs',
#    'repos_url': 'https://api.github.com/users/jrbourbeau/repos',
#    'events_url': 'https://api.github.com/users/jrbourbeau/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jrbourbeau/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 57522093,
#     'node_id': 'MDU6TGFiZWw1NzUyMjA5Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Strings',
#     'name': 'Strings',
#     'color': '5319e7',
#     'default': False,
#     'description': 'String extension data type and string data'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 5,
#   'created_at': '2022-12-05T20:49:58Z',
#   'updated_at': '2022-12-06T18:02:04Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nimport pyarrow as pa\r\n\r\ndf = pd.DataFrame({"x": ["foo", "bar", "baz"]}, dtype="string[pyarrow]")\r\n# Round-trip `df` through pyarrow using `Table.from_pandas` and `Table_to_pandas` + `types_mapper=`\r\ntypes_mapper={pa.string(): pd.ArrowDtype(pa.string())}\r\ndf_pa = pa.Table.from_pandas(df).to_pandas(types_mapper=types_mapper.get)\r\npd.testing.assert_frame_equal(df, df_pa)\r\n# The assertion above fails with:\r\n# Attribute "dtype" are different\r\n# [left]:  string[pyarrow]\r\n# [right]: string[pyarrow]\n```\n\n\n### Issue Description\n\nWhile working on improved support for `pyarrow`-backed dtypes over in Dask, I came across a case where round-tripping a DataFrame with `string[pyarrow]` dtypes doesn\'t appear to fully work as expected. \n\n### Expected Behavior\n\nWhen using `pa.Table.from_pandas` and `pa.Table.to_pandas` + `types_mapper` as described in the above example, I would expect to get an equivalent DataFrame back. \r\n\r\nAdditionally, the \r\n\r\n```\r\nAttribute "dtype" are different\r\n[left]:  string[pyarrow]\r\n[right]: string[pyarrow]\r\n```\r\n\r\nis somewhat confusing as, from the information in the error message, it actually looks like these dtypes should be the same. \r\n\n\n### Installed Versions\n\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 8dab54d6573f7186ff0c3b6364d5e4dd635ff3e7\r\npython           : 3.9.15.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 21.6.0\r\nVersion          : Darwin Kernel Version 21.6.0: Thu Sep 29 20:12:57 PDT 2022; root:xnu-8020.240.7~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.2\r\nnumpy            : 1.21.6\r\npytz             : 2022.6\r\ndateutil         : 2.8.2\r\nsetuptools       : 59.8.0\r\npip              : 22.3.1\r\nCython           : None\r\npytest           : 7.2.0\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.7.0\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : None\r\nbrotli           :\r\nfastparquet      : 2022.11.0\r\nfsspec           : 2022.11.0\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : 0.56.4\r\nnumexpr          : 2.8.3\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 10.0.1\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : 2022.11.0\r\nscipy            : 1.9.3\r\nsnappy           :\r\nsqlalchemy       : 1.4.44\r\ntables           : 3.7.0\r\ntabulate         : None\r\nxarray           : 2022.11.0\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n```\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50074/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50074/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50073',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50073/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50073/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50073/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50073',
#   'id': 1477314772,
#   'node_id': 'PR_kwDOAA0YD85EYloq',
#   'number': 50073,
#   'title': 'WIP: Dont double parse',
# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50053/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50053/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50052',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50052/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50052/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50052/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50052',
#   'id': 1474739624,
#   'node_id': 'PR_kwDOAA0YD85EPjou',
#   'number': 50052,
#   'title': 'DEPR: remove Index._is backward_compat_public_numeric_index',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-04T11:43:44Z',
#   'updated_at': '2022-12-05T23:53:13Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50052',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50052',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50052.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50052.patch',
#    'merged_at': None},
#   'body': "Removes the attribute  `Index._is backward_compat_public_numeric_index`and related stuff. This is the last PR before actually removing Int64/UInt64/Float64Index from the code base.\r\n\r\nThis PR builds on top of #49560 (which is not yet merged), so please exclude the first commit  from review of this PR.\r\n\r\nI'd also truly appreciate if someone could review #49560, as it's quite a heavy PR with lots of dtype changes.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50052/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50052/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50051',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50051/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50051/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50051/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50051',
#   'id': 1474732854,
#   'node_id': 'I_kwDOAA0YD85X5qM2',
#   'number': 50051,
#   'title': "BUG: to_datetime with decimal number doesn't fail for %Y%m%d",
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2022-12-04T11:34:07Z',
#   'updated_at': '2022-12-04T18:30:52Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nto_datetime(['19801212.0'], format='%Y%m%d', exact=True)\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nThis should fail, there's no interpretation of  `format` in which `19801212.0` matches `%Y%m%d`\r\n\r\n### Expected Behavior\r\n\r\nProbably something like\r\n```\r\nValueError: unconverted data remains: .0\r\n```\r\nbut certainly not that it passes without an error\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 732ad9f281bf6efffa12b8a872df98e18c11e3b7\r\npython           : 3.8.15.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.10.102.1-microsoft-standard-WSL2\r\nVersion          : #1 SMP Wed Mar 2 00:30:59 UTC 2022\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_GB.UTF-8\r\nLOCALE           : en_GB.UTF-8\r\n\r\npandas           : 2.0.0.dev0+838.g732ad9f281.dirty\r\nnumpy            : 1.23.5\r\npytz             : 2022.6\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.5.1\r\npip              : 22.3.1\r\nCython           : 0.29.32\r\npytest           : 7.2.0\r\nhypothesis       : 6.59.0\r\nsphinx           : 4.5.0\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 3.0.3\r\nlxml.etree       : 4.9.1\r\nhtml5lib         : 1.1\r\npymysql          : 1.0.2\r\npsycopg2         : 2.9.3\r\njinja2           : 3.0.3\r\nIPython          : 8.7.0\r\npandas_datareader: 0.10.0\r\nbs4              : 4.11.1\r\nbottleneck       : 1.3.5\r\nbrotli           : \r\nfastparquet      : 2022.11.0\r\nfsspec           : 2021.11.0\r\ngcsfs            : 2021.11.0\r\nmatplotlib       : 3.6.2\r\nnumba            : 0.56.4\r\nnumexpr          : 2.8.3\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : 0.17.9\r\npyarrow          : 9.0.0\r\npyreadstat       : 1.2.0\r\npyxlsb           : 1.0.10\r\ns3fs             : 2021.11.0\r\nscipy            : 1.9.3\r\nsnappy           : \r\nsqlalchemy       : 1.4.44\r\ntables           : 3.7.0\r\ntabulate         : 0.9.0\r\nxarray           : 2022.11.0\r\nxlrd             : 2.0.1\r\nzstandard        : 0.19.0\r\ntzdata           : None\r\nqtpy             : None\r\npyqt5            : None\r\nNone\r\n\r\n\r\n</details>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50051/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50051/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50050',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50050/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50050/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50050/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50050',
#   'id': 1474729122,
#   'node_id': 'PR_kwDOAA0YD85EPhUg',
#   'number': 50050,
#   'title': 'DOC: Add tips on where to locate test',
#   'user': {'login': 'georgemunyoro',
#    'id': 32019551,
#    'node_id': 'MDQ6VXNlcjMyMDE5NTUx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32019551?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/georgemunyoro',
#    'html_url': 'https://github.com/georgemunyoro',
#    'followers_url': 'https://api.github.com/users/georgemunyoro/followers',
#    'following_url': 'https://api.github.com/users/georgemunyoro/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/georgemunyoro/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/georgemunyoro/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/georgemunyoro/subscriptions',
#    'organizations_url': 'https://api.github.com/users/georgemunyoro/orgs',
#    'repos_url': 'https://api.github.com/users/georgemunyoro/repos',
#    'events_url': 'https://api.github.com/users/georgemunyoro/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/georgemunyoro/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-12-04T11:28:45Z',
#   'updated_at': '2022-12-06T10:40:32Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50050',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50050',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50050.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50050.patch',
#    'merged_at': None},
#   'body': 'Closes #50014',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50050/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50050/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50049',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50049/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50049/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50049/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50049',
#   'id': 1474446325,
#   'node_id': 'PR_kwDOAA0YD85EOg5w',
#   'number': 50049,
#   'title': 'DOC: Improve groupby().ngroup() explanation for missing groups',
#   'user': {'login': 'NickCrews',
#    'id': 10820686,
#    'node_id': 'MDQ6VXNlcjEwODIwNjg2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10820686?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NickCrews',
#    'html_url': 'https://github.com/NickCrews',
#    'followers_url': 'https://api.github.com/users/NickCrews/followers',
#    'following_url': 'https://api.github.com/users/NickCrews/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/NickCrews/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/NickCrews/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/NickCrews/subscriptions',
#    'organizations_url': 'https://api.github.com/users/NickCrews/orgs',
#    'repos_url': 'https://api.github.com/users/NickCrews/repos',
#    'events_url': 'https://api.github.com/users/NickCrews/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/NickCrews/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-04T04:43:20Z',
#   'updated_at': '2022-12-05T23:56:29Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50049',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50049',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50049.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50049.patch',
#    'merged_at': None},
#   'body': "The exact prose and examples are open to improvements if you have ideas.\n\nI figure this didn't require a separate issue, please let me know if I'm missing some step in the process.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50049/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50049/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
df2 = pd.DataFrame(data1 , columns=['id','url' , 'repository_url' , 'labels_url','user'])

# %%
df2.to_csv('json_res.csv')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9CD5-FCE1
#
#  Directory of C:\Users\mdimt
#
# 14-11-2022  15:31            36,257  12th Nov Live Class Functions revision.ipynb
# 07-12-2022  00:06           501,204  Working with Pandas day2 revision.ipynb
# 07-12-2022  00:06    <DIR>          .
# 07-12-2022  00:06    <DIR>          ..
# 06-11-2022  21:59    <DIR>          .anaconda
# 06-11-2022  23:06    <DIR>          .conda
# 22-05-2021  01:35                25 .condarc
# 22-05-2021  01:35    <DIR>          .continuum
# 19-10-2022  20:09                53 .git-for-windows-updater
# 01-07-2021  23:01    <DIR>          .idlerc
# 06-12-2022  22:17    <DIR>          .ipynb_checkpoints
# 22-05-2021  01:39    <DIR>          .ipython
# 29-10-2022  16:59    <DIR>          .jupyter
# 06-06-2021  02:13    <DIR>          .matplotlib
# 26-10-2022  17:39    <DIR>          .spyder-py3
# 07-10-2022  21:43    <DIR>          .vscode
# 15-11-2022  22:42    <DIR>          __pycache__
# 28-10-2022  22:49        23,553,184 1.Python Fundamentals and Advanced Python.zip
# 14-11-2022  22:32            25,125 13th Nov Live Class Functions 4 revision.ipynb
# 25-11-2022  22:47    <DIR>          19.3 MongoDB
# 23-11-2022  20:02         4,407,102 19.3 MongoDB.7z
# 31-10-2022  17:35            21,059 29th Oct Live Class Function Basic Revision.ipynb
# 21-05-2021  04:09    <DIR>          3D Objects
# 26-11-2022  16:13            27,352 6thMarch-20220803T090951Z-001.zip
# 26-11-2022  22:26             1,173 addresses.csv
# 22-05-2021  01:14    <DIR>          anaconda3
# 26-11-2022  21:17         3,381,768 archive.zip
# 21-10-2022  00:42            10,061 Assignment_1.docx
# 26-11-2022  15:50                 0 Bag of Words
# 04-12-2022  21:55           461,474 bank.csv
# 04-12-2022  21:55         4,610,348 bank-full.csv
# 04-12-2022  21:54             3,864 bank-names.txt
# 18-11-2022  17:27            51,867 car.data
# 24-11-2022  16:37           628,633 carbon_nanotubes.csv
# 19-11-2022  23:43            19,879 class assignment oops.ipynb
# 26-11-2022  16:13            79,472 class_task_MongoDB_SQlite.pdf
# 26-11-2022  16:13       120,256,543 classTask_MongoDB_SQLite-20220803T085516Z-001.zip
# 21-05-2021  04:09    <DIR>          Contacts
# 26-11-2022  22:26             1,589 contacts.csv
# 01-07-2021  23:11    <DIR>          Credit Card Risk Assessment
# 07-12-2022  00:08             5,845 cricket.csv
# 20-10-2022  20:18            59,629 demo_002.ipynb
# 26-10-2022  15:57            57,559 demo_003.ipynb
# 20-10-2022  20:20            45,893 demo_2 live_classes_ineuron_revision.ipynb
# 15-11-2022  22:42                 0 dict.log
# 21-05-2021  04:18    <DIR>          Documents
# 26-11-2022  15:46        12,313,965 docword.enron.txt.gz
# 26-11-2022  15:45         1,053,803 docword.kos.txt.gz
# 26-11-2022  15:45         2,288,169 docword.nips.txt.gz
# 26-11-2022  16:09       234,225,967 docword.nytimes.txt.gz
# 06-12-2022  23:46    <DIR>          Downloads
# 16-11-2022  13:52         3,116,878 eda_data.csv
# 19-11-2022  23:45            13,907 Exception Handling Class 2.ipynb
# 08-11-2022  21:26             9,192 Exception Handling Class1 Part1.ipynb
# 21-05-2021  04:09    <DIR>          Favorites
# 03-11-2022  00:26            10,428 For Loop & While Loops Revision.ipynb
# 03-11-2022  15:20            25,890 for loops while loop.ipynb
# 14-10-2022  00:42            10,742 FSDS_bootcamp_assignment_002_Oct_01.ipynb
# 28-10-2022  19:31             5,294 FSDS_bootcamp_assignment_004_Oct_09 (1).ipynb
# 07-11-2022  17:43            31,508 Function and holiday task.ipynb
# 06-11-2022  20:52            60,343 Function continued.ipynb
# 04-11-2022  02:08            18,716 function part1.ipynb
# 06-11-2022  00:28            62,066 function part2.ipynb
# 08-11-2022  14:44             1,763 functions task 20 question.txt
# 16-11-2022  23:44            11,903 glass.data
# 16-11-2022  13:52         3,835,251 glassdoor_jobs.csv
# 09-11-2022  22:09            43,659 holiday 20 assignment.ipynb
# 26-11-2022  22:26               277 holiday_schedules.csv
# 25-11-2022  22:44             8,192 ineuron.db
# 09-11-2022  17:43            23,501 Iterator Generator File System.ipynb
# 08-11-2022  02:20        21,685,761 iterator generator.ipynb
# 01-07-2021  23:12    <DIR>          Jedi
# 25-11-2022  19:04            12,288 jobdb.db
# 07-12-2022  00:08            34,886 json_res.csv
# 30-06-2021  14:39                 0 jupyter
# 12-05-2022  12:24    <DIR>          Links
# 26-10-2022  15:42             9,919 live_3demo_classes_ineuron_revision.ipynb
# 30-10-2022  00:07            16,593 live_classes_revision_29oct.ipynb
# 26-11-2022  22:26            18,015 locations.csv
# 15-11-2022  22:24             5,993 logging (1).ipynb
# 10-11-2022  01:53             6,194 Logging class.ipynb
# 27-11-2022  01:02           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 27-11-2022  01:02           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 27-11-2022  01:02            95,503 LUSID Excel - Manage instruments with economic definitions.xlsx
# 27-11-2022  01:02            84,319 LUSID Excel - Manage Orders.xlsx
# 27-11-2022  01:02           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 27-11-2022  01:02           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 27-11-2022  01:02           136,632 LUSID Excel - Setting up your market data.xlsx
# 26-11-2022  22:26             1,610 mail_addresses.csv
# 23-10-2022  00:20    <DIR>          Microsoft
# 19-11-2022  23:43            10,625 Module_Packages.ipynb
# 24-11-2022  16:59            75,694 mongo db class1 revision.ipynb
# 24-11-2022  20:39            57,341 mongodb class 1.ipynb
# 28-05-2022  11:32    <DIR>          Music
# 15-11-2022  22:55                 0 mydict.py
# 07-12-2022  00:07            78,961 NBA.csv
# 06-11-2022  23:23           163,679 nbextensions.ipynb
# 26-11-2022  16:11            30,814 numpy day 2.ipynb
# 06-12-2022  01:07    <DIR>          OneDrive
# 13-11-2022  22:07            39,946 oops 29th .ipynb
# 15-11-2022  22:28            43,392 oops 30th.ipynb
# 19-11-2022  23:45            41,465 oops class 1.ipynb
# 13-11-2022  19:09            40,284 Oops class part2.ipynb
# 15-11-2022  22:29            44,127 OOPs Concepts Polymorphism revision.ipynb
# 19-11-2022  23:45            11,842 Oops part1 revision.ipynb
# 26-11-2022  22:26             2,281 organizations.csv
# 26-11-2022  16:11            74,683 pandas and numpy.ipynb
# 06-12-2022  23:38           130,610 pandas class 3.ipynb
# 06-12-2022  22:17           195,692 Pandas Data Analysis Part 1 class task.ipynb
# 03-12-2022  20:25           131,403 Pandas Data Analysis Part 1 revision.ipynb
# 06-12-2022  23:58           532,860 pandas day 2.ipynb
# 06-12-2022  20:09           167,780 pandas day4 revision.ipynb
# 27-11-2022  01:06           416,711 Pandas revision.ipynb
# 25-11-2022  22:44             8,192 person.db
# 26-11-2022  22:26             2,092 phones.csv
# 23-06-2021  13:35            66,519 Pridiction Using Supervised ML.ipynb
# 24-10-2022  18:23            12,891 Programming_Assingment1.docx
# 26-11-2022  22:26                60 programs.csv
# 11-11-2022  20:19    <DIR>          PycharmProjects
# 05-11-2022  21:58             6,891 Python Basic Assignment 3.ipynb
# 08-11-2022  20:09            12,206 Python Basic Assignment 4.ipynb
# 10-11-2022  21:05             5,807 Python Basic Assignment 5.ipynb
# 15-11-2022  02:10            10,370 Python Basic Assignment 6.ipynb
# 16-11-2022  19:53             5,038 Python Basic Program Assignment 6.ipynb
# 24-11-2022  17:23             5,372 Python Basic Program Assignment 7.ipynb
# 04-12-2022  01:48             7,840 Python Basic Program Assignment 8.ipynb
# 07-11-2022  16:48            11,860 Python Basic Programming Assignment 3.ipynb
# 11-11-2022  20:38             8,306 Python Basic Programming Assignment 4.ipynb
# 14-11-2022  00:30             6,153 Python Basic Programming Assignment 5.ipynb
# 03-11-2022  20:47            14,188 Python Basics Assignment 2.ipynb
# 19-11-2022  01:20            18,535 Python Basics Assignment 7.ipynb
# 24-11-2022  23:59            12,254 Python Basics Assignment 8.ipynb
# 30-10-2022  22:54             8,022 Python Basics Assignment_1.ipynb
# 01-11-2022  15:22             8,022 Python Basics Assignment1.ipynb
# 24-10-2022  19:21             4,080 Python Basics Program Assignment1.ipynb
# 27-10-2022  21:07             4,753 Python Basics Programming_Assignment_2.ipynb
# 26-11-2022  15:45             2,170 readme.txt
# 26-11-2022  22:26               350 regular_schedules.csv
# 16-11-2022  13:52         3,100,978 salary_data_cleaned.csv
# 21-05-2021  04:09    <DIR>          Saved Games
# 04-07-2021  01:33    <DIR>          seaborn-data
# 12-05-2022  12:24    <DIR>          Searches
# 26-11-2022  22:26            19,128 services.csv
# 23-11-2022  22:57                22 Setup.zip
# 18-11-2022  21:00            80,157 SQL basic .ipynb
# 19-11-2022  23:45           358,211 sql day 2 .ipynb
# 05-12-2022  20:26            14,248 SQL lite, map, reduce, filter, zip Assignment.ipynb
# 26-11-2022  15:50            85,137 SQL lite, map, reduce, filter,zip revision.ipynb
# 18-11-2022  19:21           118,377 SQL part 1 revision.ipynb
# 25-11-2022  16:21           315,007 SQL part2 revision.ipynb
# 25-11-2022  22:42            45,270 SQLLITE ,map ,reduce ,filter,zip.ipynb
# 28-07-2021  16:17           341,881 Statistics with data science project.ipynb
# 26-11-2022  20:47             7,786 submission.csv
# 26-11-2022  22:26            14,618 taxonomy.csv
# 10-11-2022  01:52             1,807 test.log
# 03-07-2021  00:56             6,182 Test.png
# 08-11-2022  21:00                20 test.text
# 12-11-2022  15:45                 0 test1.py
# 13-11-2022  16:03                22 test1.txt
# 12-11-2022  20:51                 0 test2.py
# 13-11-2022  21:41                30 test2.tex
# 12-11-2022  15:39                 7 test3.py
# 12-11-2022  16:13                 0 test4.py
# 09-11-2022  20:02                 0 test43
# 24-06-2021  13:43            66,589 TSF GRIP Task 1 Imteyaz.ipynb
# 23-06-2021  14:11            66,518 TSF GRIP Task 1 Imteyaz-Copy1.ipynb
# 09-11-2022  19:26                22 tsst1.txt
# 06-07-2021  01:55             2,219 Tutorial 10- Seaborn- Countplot(), Violinplot(), Boxplot()- Part2.ipynb
# 03-07-2021  16:43           142,418 Tutorial 8- Matplotlib (Simple Visualization Library).ipynb
# 06-07-2021  01:46           355,324 Tutorial 9- Seaborn Tutorial- Distplot, Joinplot, Pairplot Part 1.ipynb
# 26-11-2022  16:30       201,228,288 Unconfirmed 19321.crdownload
# 02-07-2021  19:54             5,906 Untitled.ipynb
# 21-10-2022  00:41                 0 untitled.txt
# 02-07-2021  22:10            14,709 Untitled1.ipynb
# 04-11-2022  18:57            19,366 Untitled10.ipynb
# 14-11-2022  23:35            12,197 Untitled11.ipynb
# 06-11-2022  21:12            11,238 Untitled12.ipynb
# 21-11-2022  01:34             3,746 Untitled13.ipynb
# 22-11-2022  20:43           130,669 Untitled14.ipynb
# 04-10-2022  11:20            14,811 Untitled2.ipynb
# 04-10-2022  11:12               711 Untitled3.ipynb
# 05-10-2022  21:35               576 Untitled4.ipynb
# 14-10-2022  00:57             1,579 Untitled5.ipynb
# 21-10-2022  23:29           172,211 Untitled6.ipynb
# 26-10-2022  17:27            15,421 Untitled7.ipynb
# 27-10-2022  00:43             1,329 Untitled8.ipynb
# 27-10-2022  19:16             2,164 Untitled9.ipynb
# 25-04-2022  08:56    <DIR>          Videos
# 26-11-2022  15:45           236,180 vocab.enron.txt
# 26-11-2022  15:45            55,467 vocab.kos.txt
# 26-11-2022  15:45           100,807 vocab.nips.txt
# 26-11-2022  15:46         1,345,665 vocab.nytimes.txt
# 26-11-2022  15:46         1,460,248 vocab.pubmed.txt
# 22-05-2021  02:02                 0 where
# 24-11-2022  18:43         3,473,784 winrar-x64-611.exe
# 06-12-2022  00:12             5,947 Working with Python MongoDB Part1 revision.ipynb
#              165 File(s)    654,158,070 bytes
#               31 Dir(s)  185,409,708,032 bytes free
