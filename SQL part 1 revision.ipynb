# %%
# !pip install mysql-connector-python
# Out:
# ^C

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host = 'localhost', user = 'root', passwd = 'imteyaz95')
# Out:
# ...
#
# ...

# %%
mydb

# %%
mydb.cursor()

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('testineuron',),
#  ('testsudh',),
#  ('testsudhineuron',),
#  ('world',)]

# %%
cursor = mydb.cursor()

# %%
cursor.execute("create database testineuron")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     512                 query = query.encode('utf-8')
# --> 513             self._cmysql.query(query,
#     514                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Can't create database 'testineuron'; database exists
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-69-af70b617d993> in <module>
# ----> 1 cursor.execute("create database testineuron")
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
#     268         try:
# --> 269             result = self._cnx.cmd_query(stmt, raw=self._raw,
# ...

# %%
cursor.execute('create table testsudhineuron.ineuron(studentid INT(10) , firstname VARCHAR(30) ,lastname VARCHAR(30) ,regid INT(10) ,classname VARCHAR(30))')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     512                 query = query.encode('utf-8')
# --> 513             self._cmysql.query(query,
#     514                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'ineuron' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-70-50940ed3dffb> in <module>
# ----> 1 cursor.execute('create table testsudhineuron.ineuron(studentid INT(10) , firstname VARCHAR(30) ,lastname VARCHAR(30) ,regid INT(10) ,classname VARCHAR(30))')
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
# ...

# %%
cursor.execute('use testsudhineuron')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('ineuron',)]

# %%
cursor.execute('insert into testsudhineuron.ineuron values(423432,"sudh", "kumar",354543, "fsds")')

# %%
mydb.commit()

# %%
cursor.execute('select * from testsudhineuron.ineuron')

# %%
cursor.fetchall()
# Out:
# [('glassdata',), ('ineuron',)]

# %%
cursor.execute('insert into testsudhineuron.ineuron values(776556857,"ygggh", "kumar",354543, "fsds")')

# %%
cursor.execute('create table testsudhineuron.glassdata(col1 INT(10) ,col2 float(10,5) ,col3 float(10,5) ,col4 float(10,5) , col5 float(10,5) , col6 float(10,5) , col7 float(10,5) , col8 float(10,5), col9 float(10,5), col10 float(10,5), col11 float(10))')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     512                 query = query.encode('utf-8')
# --> 513             self._cmysql.query(query,
#     514                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'glassdata' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-90-08030838b3a9> in <module>
# ----> 1 cursor.execute('create table testsudhineuron.glassdata(col1 INT(10) ,col2 float(10,5) ,col3 float(10,5) ,col4 float(10,5) , col5 float(10,5) , col6 float(10,5) , col7 float(10,5) , col8 float(10,5), col9 float(10,5), col10 float(10,5), col11 float(10))')
#
# ...

# %%
cursor.execute('use testsudhineuron')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('glassdata',), ('ineuron',)]

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9CD5-FCE1
#
#  Directory of C:\Users\mdimt
#
# 14-11-2022  15:31            36,257  12th Nov Live Class Functions revision.ipynb
# 17-11-2022  00:07    <DIR>          .
# 17-11-2022  00:07    <DIR>          ..
# 06-11-2022  21:59    <DIR>          .anaconda
# 06-11-2022  23:06    <DIR>          .conda
# 22-05-2021  01:35                25 .condarc
# 22-05-2021  01:35    <DIR>          .continuum
# 19-10-2022  20:09                53 .git-for-windows-updater
# 01-07-2021  23:01    <DIR>          .idlerc
# 16-11-2022  21:42    <DIR>          .ipynb_checkpoints
# 22-05-2021  01:39    <DIR>          .ipython
# 29-10-2022  16:59    <DIR>          .jupyter
# 06-06-2021  02:13    <DIR>          .matplotlib
# 26-10-2022  17:39    <DIR>          .spyder-py3
# 07-10-2022  21:43    <DIR>          .vscode
# 15-11-2022  22:42    <DIR>          __pycache__
# ...

# %%
file = open("glass.data", 'r')

# %%
file.read()
# Out:
# '1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1\n2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1\n3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1\n4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1\n5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1\n6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1\n7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1\n8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1\n9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1\n10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1\n11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1\n12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1\n13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1\n14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1\n15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1\n16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1\n17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1\n18,1.52196,14.36,3.85,0.89,71.36,0.15,9.15,0.00,0.00,1
# ...

# %%
import csv
with open('glass.data', 'r') as f:
    glass_data = csv.reader(f, delimiter ='\n') 
    for i in glass_data:
        print(i)
# Out:
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1']
# ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1']
# ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1']
# ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1']
# ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1']
# ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1']
# ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1']
# ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1']
# ['16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1']
# ...

# %%
cursor.execute('create table testsudhineuron.glassdata(col1 INT(10) ,col2 float(10,5) ,col3 float(10,5) ,col4 float(10,5) , col5 float(10,5) , col6 float(10,5) , col7 float(10,5) , col8 float(10,5), col9 float(10,5), col10 float(10,5), col11 float(10))')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     512                 query = query.encode('utf-8')
# --> 513             self._cmysql.query(query,
#     514                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'glassdata' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-127-08030838b3a9> in <module>
# ----> 1 cursor.execute('create table testsudhineuron.glassdata(col1 INT(10) ,col2 float(10,5) ,col3 float(10,5) ,col4 float(10,5) , col5 float(10,5) , col6 float(10,5) , col7 float(10,5) , col8 float(10,5), col9 float(10,5), col10 float(10,5), col11 float(10))')
#
# ...

# %%
cursor.execute('insert into testsudhineuron.glassdata values(10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1)')

# %%
mydb.commit()

# %%
cursor.execute('select * from testsudhineuron.glassdata')

# %%
cursor.fetchall()
# Out:
# [(10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1.0)]

# %%
with open("glass.data", "r") as f:
    glass_data=csv.reader(f,delimiter='\n') 
    for i in glass_data:
        print(f'insert into glassdata1 values ({str(i[0])})')
        cursor.execute(f'insert into testsudhineuron.glassdata values({str(i[0])})')
mydb.commit()
# Out:
# insert into glassdata1 values (1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)
# insert into glassdata1 values (2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1)
# insert into glassdata1 values (3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1)
# insert into glassdata1 values (4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1)
# insert into glassdata1 values (5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1)
# insert into glassdata1 values (6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1)
# insert into glassdata1 values (7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1)
# insert into glassdata1 values (8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1)
# insert into glassdata1 values (9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1)
# insert into glassdata1 values (10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1)
# insert into glassdata1 values (11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1)
# ...

# %%
with open("glass.data", "r") as f:
    glass_data=csv.reader(f,delimiter='\n') 
    for i in glass_data:
        print(f'insert into glassdata1 values ({str(i[0])})')
        cursor.execute('insert into testsudhineuron.glassdata values({values})'.format(values=((i[0]))))
# Out:
# insert into glassdata1 values (1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)
# insert into glassdata1 values (2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1)
# insert into glassdata1 values (3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1)
# insert into glassdata1 values (4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1)
# insert into glassdata1 values (5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1)
# insert into glassdata1 values (6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1)
# insert into glassdata1 values (7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1)
# insert into glassdata1 values (8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1)
# insert into glassdata1 values (9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1)
# insert into glassdata1 values (10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1)
# insert into glassdata1 values (11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1)
# ...

# %%
mydb.commit()

# %%
import pandas as pd

# %%
pd.read_sql("select * from testsudhineuron.glassdata", mydb)
# Out:
#      col1     col2   col3  col4  col5   col6  col7  col8  col9  col10  col11
# 0      10  1.51755  13.00  3.60  1.36  72.99  0.57  8.40  0.00   0.11    1.0
# 1       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00   0.00    1.0
# 2       2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00   0.00    1.0
# 3       3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00   0.00    1.0
# 4       4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00   0.00    1.0
# ..    ...      ...    ...   ...   ...    ...   ...   ...   ...    ...    ...
# 424   210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06   0.00    7.0
# 425   211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59   0.00    7.0
# 426   212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64   0.00    7.0
# 427   213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57   0.00    7.0
# 428   214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67   0.00    7.0
#
# [429 rows x 11 columns]

# %%
pd.read_sql("show databases", mydb)
# Out:
#              Database
# 0  information_schema
# 1               mysql
# 2  performance_schema
# 3              sakila
# 4                 sys
# 5         testineuron
# 6            testsudh
# 7     testsudhineuron
# 8               world

# %%
pd.read_sql("use testsudhineuron", mydb)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-0cf939672870> in <module>
# ----> 1 pd.read_sql("use testsudhineuron", mydb)
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     493
#     494     if isinstance(pandas_sql, SQLiteDatabase):
# --> 495         return pandas_sql.read_query(
#     496             sql,
#     497             index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1770         args = _convert_params(sql, params)
#    1771         cursor = self.execute(*args)
# -> 1772         columns = [col_desc[0] for col_desc in cursor.description]
#    1773
#    1774         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable
